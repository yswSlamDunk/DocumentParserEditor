# %%
import pprint
import json

with open('역도_0000_0009.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

pprint.pprint(data)
# Out:
# {'api': '2.0',
#  'content': {'html': '<figure><img id=\'0\' alt="" '
#                      'data-coord="top-left:(50,67); bottom-right:(999,974)" '
#                      '/></figure>\n'
#                      "<h1 id='1' style='font-size:20px'><차 례></h1>\n"
#                      "<h1 id='2' style='font-size:16px'>Ⅰ. 역도의 이해 "
#                      '··························································································· '
#                      '1</h1>\n'
#                      "<br><p id='3' data-category='index' "
#                      "style='font-size:14px'>1. 역도경기의 역사 "
#                      '··························································································· '
#                      '1<br>가. 근대올림픽 대회 이전의 역도경기 '
#                      '······················································ '
#                      '1<br>나. 근대올림픽 대회 이후 역도경기 '
#                      '·························································· '
# ...

# %%
print(data.keys())

print(data['content'].keys())
# Out:
# dict_keys(['api', 'content', 'elements', 'model', 'usage'])
# dict_keys(['html', 'markdown', 'text'])

# %%
data['elements'][1]
# Out:
# {'category': 'heading1',
#  'content': {'html': "<h1 id='1' style='font-size:20px'><차 례></h1>",
#   'markdown': '',
#   'text': '<차 례>'},
#  'coordinates': [{'x': 0.4394, 'y': 0.0983},
#   {'x': 0.5578, 'y': 0.0983},
#   {'x': 0.5578, 'y': 0.1277},
#   {'x': 0.4394, 'y': 0.1277}],
#  'id': 1,
#  'page': 3}

# %%
data['elements'][3]
# Out:
# {'category': 'index',
# ...

# %%
pprint.pprint(data['content']['html'])
# Out:
# ('<figure><img id=\'0\' alt="" data-coord="top-left:(50,67); '
#  'bottom-right:(999,974)" /></figure>\n'
#  "<h1 id='1' style='font-size:20px'><차 례></h1>\n"
#  "<h1 id='2' style='font-size:16px'>Ⅰ. 역도의 이해 "
#  '··························································································· '
#  '1</h1>\n'
#  "<br><p id='3' data-category='index' style='font-size:14px'>1. 역도경기의 역사 "
#  '··························································································· '
#  '1<br>가. 근대올림픽 대회 이전의 역도경기 '
#  '······················································ 1<br>나. 근대올림픽 대회 이후 '
#  '역도경기 ·························································· 3<br>다. 우리나라 '
#  '역도경기 '
#  '················································································ '
#  '3<br>2. 역도경기의 특성 '
#  '··························································································· '
#  '6<br>가. 계체(weight-in) '
# ...
